# %%
import torch
import torch.nn as nn
from torch.utils.tensorboard import SummaryWriter
import torch.nn.functional as F
import spacy
# !jupyter nbextension enable --py widgetsnbextension
from tqdm.notebook import tqdm
from torchtext.data.metrics import bleu_score
from torchtext.data import Field, BucketIterator,TabularDataset
from torchtext.data.utils import get_tokenizer
import pandas as pd
from sklearn.model_selection import train_test_split
# CUDA=False
CUDA=torch.cuda.is_available()
device=torch.device("cuda:7" if CUDA else "cpu")
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK

# %%
with open('/mnt/disk1/Gulshan/rnn/translation/data.en1','r') as f:
    eng=f.readlines()
with open('/mnt/disk1/Gulshan/rnn/translation/data.ta1','r') as f:
    tam=f.readlines()
# a=open('/mnt/disk1/Gulshan/rnn/translation/data.en1','r')

# %%
# e1=[i.strip().split(' ') for i in tam]
# e2=[i.strip().split(' ') for i in eng]
# e1[0],e2[0]
def tokenize_(sen):
    return [word.strip() for word in sen.split(' ')]

# %%
tamil_token=Field(tokenize=tokenize_, lower=True, init_token="<sos>", eos_token="<eos>")

# %%
tamil_txt=open('/mnt/disk1/Gulshan/rnn/translation/data.ta1',encoding='utf8').read().split('\n')
english_txt=open('/mnt/disk1/Gulshan/rnn/translation/data.en1',encoding='utf8').read().split('\n')

# %%
raw_data={'English':[line for line in english_txt],
          'Tamil':[line for line in tamil_txt]}

df=pd.DataFrame(raw_data,columns=['English','Tamil'])
df.head(2)
# Out:
#                                              English
# 0  moreover all the vessels , which king ahaz in ...  \
# 1  similar conditions will be imposed if the sri ...
#
#                                                Tamil
# 0  ராஜாவாகிய ஆகாஸ் அரசாளும்போது தம்முடைய பாதகத்தி...
# 1  சர்வதேச நாணய நிதியம் இலங்கைக்கு கடன் வழங்கினால...

# %%
train_val,test=train_test_split(df,test_size=0.2)
train,val=train_test_split(train_val,test_size=0.2)
len(train_val),len(test),len(train),len(val)
# Out:
# (40000, 10001, 32000, 8000)

# %%
train.to_json('train_ml_translat.json',orient='records',lines=True)
val.to_json('val_ml_translat.json',orient='records',lines=True)
test.to_json('test_ml_translat.json',orient='records',lines=True)

# %%
def tokenize_(text):
    return [word for word in text.split(' ')]

# %%
english=Field(tokenize=tokenize_, lower=True, init_token="<start>", eos_token="<end>")
tamil=Field(tokenize=tokenize_, lower=True, init_token="<start>", eos_token="<end>")

# %%
fields={'English':('eng',english),
        'Tamil':('tam',tamil)}
# fields={'English':english,
#         'Tamil':tamil}

# %%
train_data,val_data,test_data=TabularDataset.splits(
    path='',
    train='/mnt/disk1/Gulshan/rnn/translation/train_ml_translat.json',
    validation='/mnt/disk1/Gulshan/rnn/translation/val_ml_translat.json',
    test='/mnt/disk1/Gulshan/rnn/translation/test_ml_translat.json',
    format='json',
    fields=fields
)

# %%
english.build_vocab(train_data,max_size=10000,min_freq=2)
tamil.build_vocab(train_data,max_size=10000,min_freq=2)

# %%
tamil.vocab.stoi,english.vocab.stoi
# Out:
# (defaultdict(<bound method Vocab._default_unk_index of <torchtext.vocab.Vocab object at 0x7fb4c2139c70>>,
#              {'<unk>': 0,
#               '<pad>': 1,
#               '<start>': 2,
#               '<end>': 3,
#               '.': 4,
#               ',': 5,
#               'ஒரு': 6,
#               'மற்றும்': 7,
#               'என்று': 8,
#               'இந்த': 9,
#               'நான்': 10,
#               '': 11,
#               'அவர்': 12,
#               'அமெரிக்க': 13,
#               '?': 14,
#               'வேண்டும்': 15,
#               'அது': 16,
#               'அவர்கள்': 17,
#               'என்ற': 18,
#               'என': 19,
#               'அரசியல்': 20,
#               'இது': 21,
#               'இருந்து': 22,
#               'ஆனால்': 23,
#               'நீங்கள்': 24,
#               'அந்த': 25,
#               'என்': 26,
#               'இருக்கும்': 27,
#               'அதன்': 28,
#               'பற்றி': 29,
#               'பல': 30,
#               'உள்ள': 31,
#               'இல்லை': 32,
#               'அல்லது': 33,
#               'மக்கள்': 34,
#               'கட்சி': 35,
#               'அரசாங்கம்': 36,
#               'கடந்த': 37,
#               'அவன்': 38,
#               'என்றும்': 39,
#               'தனது': 40,
#               'என்பது': 41,
#               'மீது': 42,
#               'சமூக': 43,
#               'புதிய': 44,
#               'நீ': 45,
#               'பின்னர்': 46,
#               'இரண்டு': 47,
#               'சர்வதேச': 48,
#               'வகையில்': 49,
#               'இராணுவ': 50,
#               'ஐரோப்பிய': 51,
#               'சில': 52,
#               'பொருளாதார': 53,
#               '!': 54,
#               'உள்ளது': 55,
#               'என்ன': 56,
#               'எதிராக': 57,
#               'நாம்': 58,
#               'மேலும்': 59,
#               'தான்': 60,
#               'மூலம்': 61,
#               'இன்னும்': 62,
#               'எந்த': 63,
#               'சோசலிச': 64,
#               'புஷ்': 65,
#               'தன்': 66,
#               'அமெரிக்கா': 67,
#               'அப்பொழுது': 68,
#               'முதல்': 69,
#               'பெரிய': 70,
#               'கர்த்தர்': 71,
#               'உன்': 72,
#               'என்பதை': 73,
#               'பெரும்': 74,
#               'தேசிய': 75,
#               'ஜனாதிபதி': 76,
#               'நாங்கள்': 77,
#               'தங்கள்': 78,
#               'மீண்டும்': 79,
#               'அதை': 80,
#               'கொண்டு': 81,
#               'மிக': 82,
#               'எதிரான': 83,
#               'உலக': 84,
#               'இருந்த': 85,
#               'உங்கள்': 86,
#               'ஆண்டு': 87,
#               'பற்றிய': 88,
#               'பாதுகாப்பு': 89,
#               ',000': 90,
#               'ஜனநாயக': 91,
#               'என்றார்': 92,
#               'ஆகும்': 93,
#               'முக்கிய': 94,
#               'அவரது': 95,
#               'கூறினார்': 96,
#               'படம்': 97,
#               'மிகவும்': 98,
#               'தொழிலாள': 99,
#               'முறையில்': 100,
#               'தன்னுடைய': 101,
#               'தொழிலாளர்கள்': 102,
#               'தமிழ்': 103,
#               'போர்': 104,
#               'இருந்தது': 105,
#               'வரும்': 106,
#               'தொடர்ந்து': 107,
#               'மத்திய': 108,
#               'முடியும்': 109,
#               'எனக்கு': 110,
#               'அதே': 111,
#               'கட்சியின்': 112,
#               'நிலையில்': 113,
#               'அவருடைய': 114,
#               'செய்து': 115,
#               'செய்ய': 116,
#               'தேர்தல்': 117,
#               'வருகிறது': 118,
#               'அதற்கு': 119,
#               'முதலாளித்துவ': 120,
#               'ஆதரவு': 121,
#               'மூன்று': 122,
#               'இந்தப்': 123,
#               'இரு': 124,
#               'ஈராக்': 125,
#               'தலைவர்': 126,
#               'கூட': 127,
#               'செய்தி': 128,
#               'இருக்கிறது': 129,
#               'வேலை': 130,
#               'முடியாது': 131,
#               'வரை': 132,
#               'அனைத்து': 133,
#               'என்னை': 134,
#               'இதில்': 135,
#               'கொண்ட': 136,
#               'படத்தில்': 137,
#               'அளவில்': 138,
#               'எதிர்ப்பு': 139,
#               'மில்லியன்': 140,
#               'மீதான': 141,
#               'ஏற்கனவே': 142,
#               'மாதம்': 143,
#               'போன்ற': 144,
#               'ஜனநாயகக்': 145,
#               'அரசாங்கத்தின்': 146,
#               'அவர்களை': 147,
#               'பரந்த': 148,
#               'போது': 149,
#               'மட்டுமே': 150,
#               'நோக்கி:': 151,
#               'தொழிலாளர்': 152,
#               'நேரத்தில்': 153,
#               'பேர்': 154,
#               'வந்த': 155,
#               'அல்ல': 156,
#               'ஆளும்': 157,
#               'நிர்வாகம்': 158,
#               'தமது': 159,
#               'தெரிவித்தார்': 160,
#               'போல்': 161,
#               'விடுதலைப்': 162,
#               'இந்திய': 163,
#               'அங்கு': 164,
#               'இயக்குனர்': 165,
#               'உட்பட': 166,
#               'அடிப்படையில்': 167,
#               'இருக்க': 168,
#               'தலைமை': 169,
#               'அரசாங்க': 170,
#               'படத்தின்': 171,
#               'முன்னாள்': 172,
#               'வந்து': 173,
#               'ஒன்று': 174,
#               'என்னும்': 175,
#               'அதிகாரிகள்': 176,
#               'அவை': 177,
#               'எண்ணெய்': 178,
#               'கீழ்': 179,
#               'நடவடிக்கை': 180,
#               'என்றான்': 181,
#               'தேதி': 182,
#               'மட்டும்': 183,
#               'அமெரிக்காவின்': 184,
#               'பிரெஞ்சு': 185,
#               'அவரை': 186,
#               'இப்பொழுது': 187,
#               'இத்தகைய': 188,
#               'தாக்குதல்': 189,
#               'உள்ளன': 190,
#               'கர்த்தருடைய': 191,
#               'ஐக்கிய': 192,
#               'இப்போது': 193,
#               'இராணுவம்': 194,
#               'செய்யும்': 195,
#               'அத்தகைய': 196,
#               'பங்கு': 197,
#               'வர்க்கத்தின்': 198,
#               'அடுத்த': 199,
#               'இதன்': 200,
#               'குறிப்பாக': 201,
#               'மற்ற': 202,
#               'ஒரே': 203,
#               'பில்லியன்': 204,
#               'கடுமையான': 205,
#               'சரி': 206,
#               'இவர்': 207,
#               'பிரதான': 208,
#               'இதற்கு': 209,
#               'முடிவு': 210,
#               'வேறு': 211,
#               'குறைந்த': 212,
#               'அதிக': 213,
#               'படத்தை': 214,
#               'பொது': 215,
#               'இலங்கை': 216,
#               'ஒவ்வொரு': 217,
#               'முன்னணி': 218,
#               'எப்படி': 219,
#               'குறித்து': 220,
#               'நல்ல': 221,
#               'அவர்களுடைய': 222,
#               'இந்தக்': 223,
#               'நாட்டின்': 224,
#               'முழுவதும்': 225,
#               'குழு': 226,
#               'அன்று': 227,
#               'நடந்த': 228,
#               'முழு': 229,
#               'இடையே': 230,
#               'ஒருவர்': 231,
#               'இன்று': 232,
#               'குறிப்பிட்டார்': 233,
#               'தொடர்பாக': 234,
#               'பிறகு': 235,
#               'நிதி': 236,
#               'அடிப்படை': 237,
#               'கிழக்கு': 238,
#               'அளவிற்கு': 239,
#               'சென்ற': 240,
#               'பகுதியில்': 241,
#               'முற்றிலும்': 242,
#               'அதின்': 243,
#               'அதில்': 244,
#               'அவர்களுக்கு': 245,
#               'அரசு': 246,
#               'தங்களது': 247,
#               'மாறாக': 248,
#               'மிகப்': 249,
#               'இடது': 250,
#               'நாடுகள்': 251,
#               'முன்': 252,
#               'முன்னர்': 253,
#               'இடம்': 254,
#               'உம்முடைய': 255,
#               'சகல': 256,
#               'மந்திரி': 257,
#               'விட': 258,
#               'உண்மையான': 259,
#               'சிறிய': 260,
#               'நடவடிக்கைகள்': 261,
#               'உண்மையில்': 262,
#               'இதோ': 263,
#               'மக்களின்': 264,
#               'வெற்றி': 265,
#               'காரணம்': 266,
#               'நடைபெற்ற': 267,
#               'முன்பு': 268,
#               'காலத்தில்': 269,
#               'கொள்ள': 270,
#               'சொந்த': 271,
#               'இல்லாமல்': 272,
#               'இஸ்ரவேல்': 273,
#               'ஈராக்கில்': 274,
#               'அறிக்கை': 275,
#               'என்றால்': 276,
#               'ஐந்து': 277,
#               'கொண்டுள்ளது': 278,
#               'செய்த': 279,
#               'பின்': 280,
#               'அவள்': 281,
#               'இன்': 282,
#               'எல்லா': 283,
#               'அழைப்பு': 284,
#               'தற்போது': 285,
#               'எதுவும்': 286,
#               '10': 287,
#               'கூடுதலான': 288,
#               'நீர்': 289,
#               'மனித': 290,
#               'எங்கள்': 291,
#               'இதை': 292,
#               'அவருக்கு': 293,
#               'ஓர்': 294,
#               'நாள்': 295,
#               'முறை': 296,
#               'சேர்ந்த': 297,
#               'அமைப்பு': 298,
#               'உழைக்கும்': 299,
#               'சமத்துவக்': 300,
#               'நாடு': 301,
#               'நிலை': 302,
#               'வாரம்': 303,
#               'தேவனாகிய': 304,
#               'ஆகியவை': 305,
#               'ஜேவிபி': 306,
#               'தேர்தலில்': 307,
#               'கிட்டத்தட்ட': 308,
#               'நீண்ட': 309,
#               'ஆட்சி': 310,
#               'கதை': 311,
#               'குற்றம்': 312,
#               'தவிர': 313,
#               'வாஷிங்டன்': 314,
#               'வெளியே': 315,
#               'ஆகிய': 316,
#               'இஸ்ரேல்': 317,
#               'ஏன்': 318,
#               'நடவடிக்கைகளை': 319,
#               'அடுத்து': 320,
#               'கலந்து': 321,
#               'நடந்து': 322,
#               'ல்': 323,
#               'அமைச்சர்': 324,
#               'திட்டம்': 325,
#               'நான்கு': 326,
#               'படைகள்': 327,
#               'விட்டு': 328,
#               'உரிமைகள்': 329,
#               'வலதுசாரி': 330,
#               'ஏனைய': 331,
#               'சட்ட': 332,
#               'அங்கே': 333,
#               'தலைவர்கள்': 334,
#               'அவனை': 335,
#               'எடுத்து': 336,
#               'ஜேர்மன்': 337,
#               'இங்கே': 338,
#               'தீவிர': 339,
#               'உலகம்': 340,
#               'என்றாலும்': 341,
#               'நிதிய': 342,
#               'மேலாக': 343,
#               'எனக்': 344,
#               'குமாரனாகிய': 345,
#               'இவர்கள்': 346,
#               'சதவிகிதம்': 347,
#               'மற்றொரு': 348,
#               'வந்தது': 349,
#               '1': 350,
#               '20': 351,
#               'உதவி': 352,
#               'தனியார்': 353,
#               'இங்கு': 354,
#               'இந்தியா': 355,
#               'உங்களுக்கு': 356,
#               'எனவே': 357,
#               'தொடர்பான': 358,
#               'ஐநா': 359,
#               'காங்கிரஸ்': 360,
#               'மக்களை': 361,
#               'உடனடியாக': 362,
#               'வெளிநாட்டு': 363,
#               'இணைந்து': 364,
#               'கம்யூனிஸ்ட்': 365,
#               'நிறுவனம்': 366,
#               'இரண்டாம்': 367,
#               'ஏனெனில்': 368,
#               'நெருக்கடி': 369,
#               'பிரிட்டிஷ்': 370,
#               'பெற்ற': 371,
#               'அமெரிக்காவில்': 372,
#               'கொடுக்கும்': 373,
#               'பின்பு': 374,
#               'உமது': 375,
#               'உள்நாட்டு': 376,
#               'மே': 377,
#               'யார்': 378,
#               'அளவு': 379,
#               'ஒன்றை': 380,
#               'கொள்கை': 381,
#               'அதாவது': 382,
#               'உறுப்பினர்கள்': 383,
#               'தகவல்': 384,
#               'தற்போதைய': 385,
#               'நேற்று': 386,
#               'பிரதமர்': 387,
#               'போய்': 388,
#               'கருத்து': 389,
#               'பணம்': 390,
#               'முக்கியமான': 391,
#               ':': 392,
#               'அனைவரும்': 393,
#               'கூட்டணி': 394,
#               'கைது': 395,
#               'இஸ்ரேலிய': 396,
#               'எண்ணிக்கை': 397,
#               'நிர்வாகத்தின்': 398,
#               'பழைய': 399,
#               'பெயர்': 400,
#               'போதிலும்': 401,
#               'வைத்து': 402,
#               'உற்பத்தி': 403,
#               'எடுத்துக்': 404,
#               'தொடர்பு': 405,
#               'நிறுவனங்கள்': 406,
#               'பகுதி': 407,
#               'பகுதிகளில்': 408,
#               'வர்க்கம்': 409,
#               '2': 410,
#               'அப்படியே': 411,
#               'அறிவித்தார்': 412,
#               'இரண்டாவது': 413,
#               'க்கு': 414,
#               'எனது': 415,
#               'சேர்ந்து': 416,
#               'தேவனுடைய': 417,
#               'மத்தியில்': 418,
#               'வலைத்': 419,
#               'கடன்': 420,
#               'செய்தது': 421,
#               'நேரம்': 422,
#               '30': 423,
#               'இப்படி': 424,
#               'இவை': 425,
#               'தன்மை': 426,
#               'தொழிற்சங்க': 427,
#               'பதிலாக': 428,
#               'புலிகள்': 429,
#               'மேல்': 430,
#               'வடக்கு': 431,
#               'விடுதலை': 432,
#               'இதர': 433,
#               'உரிமை': 434,
#               'ஒன்றும்': 435,
#               'சென்று': 436,
#               'அவர்களது': 437,
#               'இல்லாத': 438,
#               'உனக்கு': 439,
#               'சோவியத்': 440,
#               'தன்னை': 441,
#               'முடியாத': 442,
#               'கொடுக்க': 443,
#               'சிறந்த': 444,
#               'தேவை': 445,
#               'உன்னை': 446,
#               'துருப்புக்கள்': 447,
#               'நலன்களை': 448,
#               'பெரும்பாலான': 449,
#               'அவர்களின்': 450,
#               'காரணமாக': 451,
#               'நடந்தது': 452,
#               'மக்களுக்கு': 453,
#               'வருகின்றன': 454,
#               'வளர்ச்சி': 455,
#               'வேண்டிய': 456,
#               '3': 457,
#               'செப்டம்பர்': 458,
#               'டைம்ஸ்': 459,
#               'ஆறு': 460,
#               'ஐ': 461,
#               'குழுவின்': 462,
#               'நடிக்க': 463,
#               '15': 464,
#               'அரசாங்கத்தை': 465,
#               'போருக்கு': 466,
#               'போலீஸ்': 467,
#               'அவனுக்கு': 468,
#               'உள்ளனர்': 469,
#               'எதிர்ப்பை': 470,
#               'கட்சிகள்': 471,
#               'சதவீதம்': 472,
#               'செய்தார்': 473,
#               'பல்வேறு': 474,
#               '5': 475,
#               'ஆண்டுகளில்': 476,
#               'ஆண்டுகளுக்கு': 477,
#               'உள்ளூர்': 478,
#               'கணிசமான': 479,
#               'புலிகளின்': 480,
#               'இராஜபக்ஷ': 481,
#               'சுதந்திர': 482,
#               'தலைமையிலான': 483,
#               'யின்': 484,
#               'விரைவில்': 485,
#               'அந்தப்': 486,
#               'ஆதரவை': 487,
#               'இனி': 488,
#               'இல்': 489,
#               'சாதாரண': 490,
#               'சோசலிஸ்ட்': 491,
#               'பார்க்க': 492,
#               'பிரான்ஸ்': 493,
#               'யுத்த': 494,
#               'என்னவென்றால்': 495,
#               'என்பதில்': 496,
#               'சீனா': 497,
#               'தேவன்': 498,
#               'நன்கு': 499,
#               'முயற்சி': 500,
#               '25': 501,
#               'சென்னை': 502,
#               'தெரியும்': 503,
#               'தொழிலாளர்களை': 504,
#               'பெற': 505,
#               'முதலில்': 506,
#               'ஆகையால்': 507,
#               'இதுவரை': 508,
#               'உலகின்': 509,
#               'எங்களுக்கு': 510,
#               'சோசக': 511,
#               'ஜூலை': 512,
#               'திரும்ப': 513,
#               'தொழில்': 514,
#               'நிலைமை': 515,
#               'முக்கியத்துவம்': 516,
#               'ராஜா': 517,
#               'இதே': 518,
#               'இந்தத்': 519,
#               'ஏகாதிபத்திய': 520,
#               'கிடைக்கும்': 521,
#               'குமாரன்': 522,
#               'துணை': 523,
#               'நடித்த': 524,
#               'மிகக்': 525,
#               'விசாரணை': 526,
#               'ஆனாலும்': 527,
#               'இருந்தாலும்': 528,
#               'உயர்': 529,
#               'உலகப்': 530,
#               'குண்டு': 531,
#               'கொண்டுள்ள': 532,
#               'பிரதம': 533,
#               'மேற்கு': 534,
#               'கொண்டிருக்கிறது': 535,
#               'ஜனவரி': 536,
#               'ஜேர்மனிய': 537,
#               'தொழிற்சங்கங்கள்': 538,
#               'மார்ச்': 539,
#               'ஏழு': 540,
#               'தடை': 541,
#               'திட்டத்தை': 542,
#               'நடிகர்': 543,
#               'முன்பாக': 544,
#               'வருகிறார்': 545,
#               'அதிகம்': 546,
#               'அனைத்தும்': 547,
#               'அவனுடைய': 548,
#               'இராணுவத்': 549,
#               'இருப்பதாக': 550,
#               'உண்டு': 551,
#               'செய்யப்பட்ட': 552,
#               'போரை': 553,
#               'வெள்ளை': 554,
#               '40': 555,
#               'அரசாங்கத்திற்கு': 556,
#               'இறுதியில்': 557,
#               'எதிர்த்து': 558,
#               'ஒருவன்': 559,
#               'கிடையாது': 560,
#               'கொண்டது': 561,
#               'சட்டம்': 562,
#               'சொல்லி': 563,
#               'நாடுகளில்': 564,
#               'படப்பிடிப்பு': 565,
#               'பயங்கரவாத': 566,
#               'வெளியுறவு': 567,
#               'ஏதும்': 568,
#               'சமாதான': 569,
#               'ஜனங்கள்': 570,
#               'தெற்கு': 571,
#               'தொழிலாளர்களின்': 572,
#               'நம்பிக்கை': 573,
#               '4': 574,
#               'அதிகாரி': 575,
#               'இயக்கம்': 576,
#               'இஸ்லாமிய': 577,
#               'எமது': 578,
#               'கூட்டத்தில்': 579,
#               'கண்டு': 580,
#               'நாணய': 581,
#               'பலர்': 582,
#               'ரஷ்ய': 583,
#               'ஒன்றில்': 584,
#               'தெளிவாக': 585,
#               'பாராளுமன்ற': 586,
#               'மணி': 587,
#               'வழி': 588,
#               '12': 589,
#               'கணக்கான': 590,
#               'கொண்டிருக்கும்': 591,
#               'சுமார்': 592,
#               'தமிழீழ': 593,
#               'அமெரிக்கப்': 594,
#               'எல்லாம்': 595,
#               'கால': 596,
#               'கொள்ளும்': 597,
#               'சமீபத்தில்': 598,
#               'தாக்குதல்கள்': 599,
#               'மாணவர்கள்': 600,
#               'மூலோபாய': 601,
#               'வர்க்க': 602,
#               'வர்த்தக': 603,
#               '100': 604,
#               '50': 605,
#               'அண்மையில்': 606,
#               'இடையில்': 607,
#               'இஸ்ரவேலின்': 608,
#               'ஈரான்': 609,
#               'உயர்ந்த': 610,
#               'குறிப்பிடத்தக்க': 611,
#               'கூடும்': 612,
#               'சிங்கள': 613,
#               'ஜூன்': 614,
#               'தலைவரான': 615,
#               'நடிக்கிறார்': 616,
#               'போரில்': 617,
#               'அழுத்தம்': 618,
#               'இதனால்': 619,
#               'ஈராக்கிய': 620,
#               'உடைய': 621,
#               'கூட்டு': 622,
#               'நடக்கும்': 623,
#               'முந்தைய': 624,
#               'அதிகமாக': 625,
#               'கடுமையாக': 626,
#               'நாட்டில்': 627,
#               'நிறைய': 628,
#               'பயன்படுத்தி': 629,
#               'ராஜாவாகிய': 630,
#               '11': 631,
#               'எந்தவொரு': 632,
#               'டாலர்': 633,
#               'தன்மையை': 634,
#               'நடத்திய': 635,
#               'போராட்டம்': 636,
#               'முதலாளித்துவத்தின்': 637,
#               'ஆரம்பத்தில்': 638,
#               'ஆழ்ந்த': 639,
#               'எதையும்': 640,
#               'காட்டுகிறது': 641,
#               'தாங்கள்': 642,
#               'பதில்': 643,
#               'பாடல்': 644,
#               'மொத்த': 645,
#               'விதத்தில்': 646,
#               'அணு': 647,
#               'ஆண்டுகளாக': 648,
#               'இருவரும்': 649,
#               'ஒபாமா': 650,
#               'கொண்டிருந்த': 651,
#               'கொண்டு': 652,
#               'சீன': 653,
#               'தயாராக': 654,
#               'நவம்பர்': 655,
#               'நாட்கள்': 656,
#               'மாநில': 657,
#               'வேண்டாம்': 658,
#               'ஆகஸ்ட்': 659,
#               'ஆப்கானிஸ்தானில்': 660,
#               'கொழும்பு': 661,
#               'சிறப்பு': 662,
#               'சிலர்': 663,
#               'சுகாதார': 664,
#               'தெலுங்கு': 665,
#               'நாடுகளின்': 666,
#               'நான்காம்': 667,
#               'நிர்வாக': 668,
#               'வரலாற்று': 669,
#               'இந்தியாவின்': 670,
#               'இருந்தார்': 671,
#               'இறுதி': 672,
#               'ஒன்றியம்': 673,
#               'காதல்': 674,
#               'தாக்குதலை': 675,
#               'நிலையை': 676,
#               'மிகுந்த': 677,
#               'மூத்த': 678,
#               '6': 679,
#               'அக்டோபர்': 680,
#               'அதனால்': 681,
#               'அந்தக்': 682,
#               'உங்களை': 683,
#               'உரிமைகளை': 684,
#               'கூடிய': 685,
#               'மேற்பட்ட': 686,
#               'விஜய்': 687,
#               'ஸ்ராலினிச': 688,
#               'இன்றைய': 689,
#               'இயேசு': 690,
#               'இருக்கிற': 691,
#               'உடன்': 692,
#               'காலம்': 693,
#               'கீழே': 694,
#               'கையில்': 695,
#               'சந்தை': 696,
#               'சிறு': 697,
#               'செல்ல': 698,
#               'செல்லும்': 699,
#               'தொடர்ந்து': 700,
#               'நடத்த': 701,
#               'ன்': 702,
#               'மிகப்பெரிய': 703,
#               'வெளிப்படையாக': 704,
#               'அதிகமான': 705,
#               'ஆயுதங்கள்': 706,
#               'உணவு': 707,
#               'என்பதால்': 708,
#               'ஏற்பாடு': 709,
#               'கண்டனம்': 710,
#               'கார்': 711,
#               'கிழக்கில்': 712,
#               'குடியரசுக்': 713,
#               'ஜேர்மனி': 714,
#               'பரிசுத்த': 715,
#               'பிரிவு': 716,
#               'பிற': 717,
#               'முழுவதிலும்': 718,
#               'இசை': 719,
#               'இடத்தில்': 720,
#               'கூறி': 721,
#               'தடுத்து': 722,
#               'தனிப்பட்ட': 723,
#               'தலைமையில்': 724,
#               'பணி': 725,
#               'பிரச்சாரம்': 726,
#               'பிரதிநிதிகள்': 727,
#               'மீதும்': 728,
#               'முன்னதாக': 729,
#               'ரஜினி': 730,
#               'வயது': 731,
#               'இப்போது': 732,
#               'ஏதாவது': 733,
#               'ஒப்பந்தம்': 734,
#               'ஓ': 735,
#               'படங்கள்': 736,
#               'பெரிதும்': 737,
#               'பொருளாதாரம்': 738,
#               'மாநாட்டில்': 739,
#               'விட்டது': 740,
#               '8': 741,
#               'ஆக்கிரமிப்பு': 742,
#               'ஆட்சியை': 743,
#               'ஆயினும்': 744,
#               'இடங்களில்': 745,
#               'இரவு': 746,
#               'உண்மை': 747,
#               'எனவும்': 748,
#               'நம்முடைய': 749,
#               'நிறைந்த': 750,
#               'பற்றியும்': 751,
#               'பாக்கிஸ்தான்': 752,
#               '7': 753,
#               'இருக்கிறார்': 754,
#               'என்பதற்கு': 755,
#               'என்றார்கள்': 756,
#               'எல்லாரும்': 757,
#               'கிடைத்தது': 758,
#               'சமீபத்திய': 759,
#               'செயலாளர்': 760,
#               'நடத்தி': 761,
#               'நெருக்கமான': 762,
#               'மோசமான': 763,
#               'யுத்தத்தை': 764,
#               'யுத்தம்': 765,
#               'அறிக்கையில்': 766,
#               'உறுதி': 767,
#               'கூடாது': 768,
#               'கொடுத்த': 769,
#               'செய்வதற்கு': 770,
#               'ஜேர்மனியில்': 771,
#               'டிசம்பர்': 772,
#               'நேரடியாக': 773,
#               'பிரான்சின்': 774,
#               'பூகோள': 775,
#               'பெயரில்': 776,
#               'மாதங்களில்': 777,
#               'ஈராக்கிற்கு': 778,
#               'ஏப்ரல்': 779,
#               'கருத்தை': 780,
#               'தெளிவான': 781,
#               'நிறுத்த': 782,
#               'பிரகடனம்': 783,
#               'வங்கி': 784,
#               'விலை': 785,
#               'விளைவாக': 786,
#               'வேலைகள்': 787,
#               'ஆக': 788,
#               'ஆஸ்திரேலிய': 789,
#               'உத்தியோகபூர்வ': 790,
#               'உறுப்பினர்': 791,
#               'கட்சியை': 792,
#               'கொள்கைகளை': 793,
#               'சார்க்கோசி': 794,
#               'தொழிலாளர்களுக்கு': 795,
#               'நோக்கம்': 796,
#               'பதவி': 797,
#               'முழுமையாக': 798,
#               'வழக்கு': 799,
#               'வாழ்க்கை': 800,
#               'அருகில்': 801,
#               'அவர்களில்': 802,
#               'உறுதியாக': 803,
#               'என்னுடைய': 804,
#               'ஒப்புக்': 805,
#               'கூட்டம்': 806,
#               'டாலர்கள்': 807,
#               'தவிர்க்க': 808,
#               'பத்திரிகை': 809,
#               'பிளேயர்': 810,
#               'பெறும்': 811,
#               'பொருள்': 812,
#               'ஆண்டுகள்': 813,
#               'இந்தச்': 814,
#               'இருந்தன': 815,
#               'கூறியுள்ளார்': 816,
#               'கொண்டார்': 817,
#               'கொலை': 818,
#               'தகவல்கள்': 819,
#               'தண்ணீர்': 820,
#               'தனக்கு': 821,
#               'பசுமைக்': 822,
#               'முடியவில்லை': 823,
#               'வணிக': 824,
#               'விருது': 825,
#               'விரோத': 826,
#               'அவற்றின்': 827,
#               'உணர்வு': 828,
#               'எந்தவிதமான': 829,
#               'ஐரோப்பா': 830,
#               'கட்டுப்பாட்டில்': 831,
#               'செய்தனர்': 832,
#               'தங்களுடைய': 833,
#               'தயாரிப்பாளர்': 834,
#               'தாம்': 835,
#               'தெரியாது': 836,
#               'தேவையான': 837,
#               'நமது': 838,
#               'பாலஸ்தீனிய': 839,
#               'பேரழிவு': 840,
#               'மறு': 841,
#               'வேலையின்மை': 842,
#               'அமைப்பின்': 843,
#               'அரசாங்கங்கள்': 844,
#               'இனவாத': 845,
#               'இளைஞர்கள்': 846,
#               'ஏற்பட்ட': 847,
#               'ஒன்றியத்தின்': 848,
#               'குறிப்பிட்ட': 849,
#               'கொடுத்து': 850,
#               'தம்முடைய': 851,
#               'தளபதி': 852,
#               'பதிவு': 853,
#               'பிரிட்டன்': 854,
#               'மருத்துவ': 855,
#               'மோசே': 856,
#               'வந்துள்ளது': 857,
#               'அதேவேளை': 858,
#               'அமெரிக்கத்': 859,
#               'அமைப்புக்கள்': 860,
#               'அவற்றை': 861,
#               'ஆய்வு': 862,
#               'இலக்கு': 863,
#               'கொள்கைகள்': 864,
#               'சொல்லுகிறார்': 865,
#               'தக்க': 866,
#               'நாட்டை': 867,
#               'நூற்றுக்கணக்கான': 868,
#               'பாகிஸ்தான்': 869,
#               'பார்த்து': 870,
#               'பாலஸ்தீன': 871,
#               'பொதுவாக': 872,
#               'மகத்தான': 873,
#               'மூன்றாம்': 874,
#               'வாழ்க்கைத்': 875,
#               'விமான': 876,
#               'அரச': 877,
#               'ஆதரவாளர்கள்': 878,
#               'எங்களை': 879,
#               'எடுக்க': 880,
#               'கர்த்தராகிய': 881,
#               'பாரிய': 882,
#               'பேரில்': 883,
#               'போலவே': 884,
#               'வர்க்கத்தை': 885,
#               '60': 886,
#               'அச்சுறுத்தல்': 887,
#               'அடையாளம்': 888,
#               'அதிகாரத்தை': 889,
#               'அமெரிக்காவிற்கு': 890,
#               'ஆகியவற்றை': 891,
#               'இராணுவத்தின்': 892,
#               'இலங்கையில்': 893,
#               'உயர்மட்ட': 894,
#               'எரிவாயு': 895,
#               'குறுகிய': 896,
#               'சக்தி': 897,
#               'சமுதாய': 898,
#               'தங்களின்': 899,
#               'தமிழில்': 900,
#               'தாக்குதல்களை': 901,
#               'திரும்பி': 902,
#               'நேட்டோ': 903,
#               'பங்கை': 904,
#               'பேச்சு': 905,
#               'மகன்': 906,
#               'வருகின்றனர்': 907,
#               'அதைக்': 908,
#               'அனைத்தையும்': 909,
#               'இடையிலான': 910,
#               'இருக்கின்றன': 911,
#               'இருப்பது': 912,
#               'ஊழியர்கள்': 913,
#               'ஒட்டி': 914,
#               'கவலை': 915,
#               'குறைந்தது': 916,
#               'கூறியுள்ளது': 917,
#               'கொள்கையை': 918,
#               'சினிமா': 919,
#               'செய்வது': 920,
#               'தயாரிப்பாளர்கள்': 921,
#               'துறை': 922,
#               'தொகை': 923,
#               'நடிக்கும்': 924,
#               'நாட்களில்': 925,
#               'நிலைமையை': 926,
#               'பிரச்சினை': 927,
#               'பொலிஸ்': 928,
#               'மனைவி': 929,
#               'முயற்சியில்': 930,
#               'யூனியன்': 931,
#               'அதைப்': 932,
#               'அவைகள்': 933,
#               'ஆசிரியர்': 934,
#               'ஆட்சிக்கு': 935,
#               'ஆயுதங்களை': 936,
#               'இரகசிய': 937,
#               'எங்கே': 938,
#               'ஏற்படும்': 939,
#               'ஒப்புதல்': 940,
#               'சார்பில்': 941,
#               'ஜெனரல்': 942,
#               'ஜோன்': 943,
#               'தொடக்கத்தில்': 944,
#               'நடவடிக்கையை': 945,
#               'பதவியில்': 946,
#               'வாய்ப்பு': 947,
#               'விரும்பவில்லை': 948,
#               '17': 949,
#               'அரசியலமைப்பு': 950,
#               'அறிக்கையை': 951,
#               'இதனை': 952,
#               'இதுதான்': 953,
#               'இந்து': 954,
#               'இவன்': 955,
#               'ஈராக்கின்': 956,
#               'என்பதாகும்': 957,
#               'ஏற்பட்டது': 958,
#               'குழுக்கள்': 959,
#               'சார்ந்த': 960,
#               'சீனாவின்': 961,
#               'சுற்றி': 962,
#               'தரும்': 963,
#               'தேர்வு': 964,
#               'நினைக்கிறேன்': 965,
#               'பகுதியாக': 966,
#               'புரிந்து': 967,
#               'புலிகளுக்கு': 968,
#               'பேச்சுவார்த்தை': 969,
#               'அரசியலில்': 970,
#               'அவரின்': 971,
#               'ஆகியவற்றின்': 972,
#               'உடன்பாடு': 973,
#               'எவரும்': 974,
#               'ஏனென்றால்': 975,
#               'சபை': 976,
#               'சரியான': 977,
#               'தெரிகிறது': 978,
#               'நிலைப்பாட்டை': 979,
#               'படங்களில்': 980,
#               'பின்னால்': 981,
#               'புது': 982,
#               'மாற்றம்': 983,
#               'முதலாவது': 984,
#               'ம்': 985,
#               'வெறும்': 986,
#               'அகிலத்தின்': 987,
#               'அபிவிருத்தி': 988,
#               'ஆப்கானிஸ்தான்': 989,
#               'இதையொட்டி': 990,
#               'இயக்கத்தில்': 991,
#               'ஏராளமான': 992,
#               'ஒன்றிய': 993,
#               'கூறினார்:': 994,
#               'கொண்டிருந்தது': 995,
#               'கேட்டு': 996,
#               'தேர்தல்களில்': 997,
#               'பிரச்சாரத்தை': 998,
#               'முடிந்தது': 999,
#               ...}),
#  defaultdict(<bound method Vocab._default_unk_index of <torchtext.vocab.Vocab object at 0x7fb4cdaae640>>,
#              {'<unk>': 0,
#               '<pad>': 1,
#               '<start>': 2,
#               '<end>': 3,
#               'the': 4,
#               ',': 5,
#               '.': 6,
#               'of': 7,
#               'and': 8,
#               'to': 9,
#               'in': 10,
#               'a': 11,
#               "'": 12,
#               'that': 13,
#               'is': 14,
#               'for': 15,
#               "'s": 16,
#               'on': 17,
#               'it': 18,
#               'with': 19,
#               'was': 20,
#               'by': 21,
#               'as': 22,
#               'you': 23,
#               'he': 24,
#               'be': 25,
#               'has': 26,
#               'have': 27,
#               'i': 28,
#               'not': 29,
#               'his': 30,
#               'this': 31,
#               'are': 32,
#               'from': 33,
#               'they': 34,
#               'at': 35,
#               'an': 36,
#               'will': 37,
#               'but': 38,
#               'us': 39,
#               'all': 40,
#               'their': 41,
#               'which': 42,
#               'were': 43,
#               'its': 44,
#               'shall': 45,
#               'government': 46,
#               'had': 47,
#               'been': 48,
#               'said': 49,
#               '?': 50,
#               'we': 51,
#               'him': 52,
#               'people': 53,
#               'there': 54,
#               'out': 55,
#               'them': 56,
#               'one': 57,
#               'your': 58,
#               'film': 59,
#               'no': 60,
#               'who': 61,
#               'against': 62,
#               'up': 63,
#               'war': 64,
#               'my': 65,
#               'lord': 66,
#               'or': 67,
#               'would': 68,
#               'party': 69,
#               'when': 70,
#               'more': 71,
#               'also': 72,
#               'after': 73,
#               'me': 74,
#               'over': 75,
#               'political': 76,
#               'into': 77,
#               'only': 78,
#               'now': 79,
#               'what': 80,
#               'any': 81,
#               'about': 82,
#               'military': 83,
#               'her': 84,
#               'so': 85,
#               'if': 86,
#               'other': 87,
#               'these': 88,
#               'new': 89,
#               'world': 90,
#               'workers': 91,
#               'even': 92,
#               'two': 93,
#               'do': 94,
#               'she': 95,
#               'than': 96,
#               'working': 97,
#               'made': 98,
#               'percent': 99,
#               'can': 100,
#               'then': 101,
#               'social': 102,
#               'last': 103,
#               'such': 104,
#               'time': 105,
#               "'t": 106,
#               'state': 107,
#               'god': 108,
#               'before': 109,
#               'iraq': 110,
#               'bush': 111,
#               'years': 112,
#               'israel': 113,
#               'class': 114,
#               'international': 115,
#               'like': 116,
#               '!': 117,
#               'under': 118,
#               'day': 119,
#               'being': 120,
#               'did': 121,
#               'come': 122,
#               'some': 123,
#               'first': 124,
#               'house': 125,
#               'many': 126,
#               'while': 127,
#               'because': 128,
#               'country': 129,
#               'economic': 130,
#               'most': 131,
#               'year': 132,
#               'could': 133,
#               'our': 134,
#               'president': 135,
#               'just': 136,
#               'well': 137,
#               'administration': 138,
#               'american': 139,
#               'man': 140,
#               'came': 141,
#               'minister': 142,
#               'between': 143,
#               'go': 144,
#               'should': 145,
#               'tamil': 146,
#               '000': 147,
#               'make': 148,
#               'those': 149,
#               'socialist': 150,
#               'union': 151,
#               'place': 152,
#               'since': 153,
#               'may': 154,
#               'take': 155,
#               'support': 156,
#               'down': 157,
#               'son': 158,
#               'democratic': 159,
#               'both': 160,
#               'left': 161,
#               'according': 162,
#               'national': 163,
#               'opposition': 164,
#               'ltte': 165,
#               'own': 166,
#               'police': 167,
#               'election': 168,
#               'took': 169,
#               'another': 170,
#               'through': 171,
#               'right': 172,
#               'get': 173,
#               'where': 174,
#               'european': 175,
#               'however': 176,
#               'how': 177,
#               'films': 178,
#               'way': 179,
#               'children': 180,
#               'king': 181,
#               'know': 182,
#               'public': 183,
#               'told': 184,
#               'every': 185,
#               'same': 186,
#               'went': 187,
#               'three': 188,
#               'role': 189,
#               'days': 190,
#               'forces': 191,
#               'including': 192,
#               'power': 193,
#               'crisis': 194,
#               'part': 195,
#               'states': 196,
#               'hand': 197,
#               'security': 198,
#               'let': 199,
#               'work': 200,
#               'among': 201,
#               'back': 202,
#               'good': 203,
#               'sri': 204,
#               'already': 205,
#               'india': 206,
#               'washington': 207,
#               'end': 208,
#               'campaign': 209,
#               'rights': 210,
#               'men': 211,
#               'say': 212,
#               'without': 213,
#               'united': 214,
#               'very': 215,
#               'parties': 216,
#               'called': 217,
#               'must': 218,
#               'city': 219,
#               'during': 220,
#               'see': 221,
#               'major': 222,
#               'media': 223,
#               'put': 224,
#               'give': 225,
#               'land': 226,
#               'off': 227,
#               'director': 228,
#               'foreign': 229,
#               'saying': 230,
#               'given': 231,
#               'french': 232,
#               'great': 233,
#               'within': 234,
#               'east': 235,
#               'policy': 236,
#               'why': 237,
#               'general': 238,
#               'don': 239,
#               'am': 240,
#               'much': 241,
#               'here': 242,
#               'million': 243,
#               'declared': 244,
#               'trade': 245,
#               'financial': 246,
#               'number': 247,
#               'peace': 248,
#               'interests': 249,
#               'set': 250,
#               'countries': 251,
#               'next': 252,
#               'story': 253,
#               'europe': 254,
#               'movement': 255,
#               'times': 256,
#               'troops': 257,
#               'far': 258,
#               'german': 259,
#               'ruling': 260,
#               'china': 261,
#               'week': 262,
#               'france': 263,
#               'name': 264,
#               'life': 265,
#               'population': 266,
#               'does': 267,
#               'regime': 268,
#               'past': 269,
#               "'re": 270,
#               'former': 271,
#               'further': 272,
#               'away': 273,
#               'again': 274,
#               'father': 275,
#               'months': 276,
#               'still': 277,
#               'taken': 278,
#               'members': 279,
#               'brought': 280,
#               'done': 281,
#               'prime': 282,
#               'things': 283,
#               'north': 284,
#               'system': 285,
#               'law': 286,
#               'oil': 287,
#               'army': 288,
#               'indian': 289,
#               'yet': 290,
#               'billion': 291,
#               'south': 292,
#               'struggle': 293,
#               'leader': 294,
#               'attack': 295,
#               'court': 296,
#               'middle': 297,
#               'call': 298,
#               'order': 299,
#               'program': 300,
#               'sep': 301,
#               'following': 302,
#               'attacks': 303,
#               'death': 304,
#               'business': 305,
#               'long': 306,
#               'meeting': 307,
#               'therefore': 308,
#               'month': 309,
#               'around': 310,
#               'official': 311,
#               'press': 312,
#               'unions': 313,
#               'action': 314,
#               'behold': 315,
#               'case': 316,
#               'conditions': 317,
#               'control': 318,
#               'gave': 319,
#               'mass': 320,
#               'want': 321,
#               'iran': 322,
#               'going': 323,
#               'high': 324,
#               'itself': 325,
#               'nothing': 326,
#               'global': 327,
#               'leaders': 328,
#               'got': 329,
#               'secretary': 330,
#               'several': 331,
#               'elections': 332,
#               "'m": 333,
#               'central': 334,
#               'face': 335,
#               'four': 336,
#               'killed': 337,
#               'afghanistan': 338,
#               'held': 339,
#               'policies': 340,
#               'too': 341,
#               'germany': 342,
#               'report': 343,
#               'officials': 344,
#               '2': 345,
#               'economy': 346,
#               'five': 347,
#               'powers': 348,
#               'second': 349,
#               'themselves': 350,
#               'found': 351,
#               'used': 352,
#               'iraqi': 353,
#               'money': 354,
#               'force': 355,
#               'old': 356,
#               'act': 357,
#               'cannot': 358,
#               'david': 359,
#               'few': 360,
#               'little': 361,
#               'office': 362,
#               'pakistan': 363,
#               'clear': 364,
#               'fire': 365,
#               'lanka': 366,
#               'region': 367,
#               'need': 368,
#               'young': 369,
#               'chief': 370,
#               'living': 371,
#               'recent': 372,
#               'use': 373,
#               '10': 374,
#               'fact': 375,
#               'present': 376,
#               'strike': 377,
#               'least': 378,
#               '1': 379,
#               'sent': 380,
#               'bring': 381,
#               'big': 382,
#               'having': 383,
#               'capitalist': 384,
#               'congress': 385,
#               'measures': 386,
#               'nor': 387,
#               'vote': 388,
#               'british': 389,
#               'together': 390,
#               'never': 391,
#               'himself': 392,
#               'majority': 393,
#               'shooting': 394,
#               'sons': 395,
#               'nuclear': 396,
#               'released': 397,
#               'announced': 398,
#               'asked': 399,
#               'bank': 400,
#               'o': 401,
#               'means': 402,
#               'position': 403,
#               'think': 404,
#               'eu': 405,
#               'un': 406,
#               'cut': 407,
#               'directed': 408,
#               'rajapakse': 409,
#               'thus': 410,
#               'based': 411,
#               'decision': 412,
#               'home': 413,
#               'neither': 414,
#               'until': 415,
#               'others': 416,
#               'situation': 417,
#               'result': 418,
#               'earth': 419,
#               'occupation': 420,
#               'company': 421,
#               'hero': 422,
#               'jobs': 423,
#               'music': 424,
#               'seen': 425,
#               'today': 426,
#               'main': 427,
#               'might': 428,
#               'weapons': 429,
#               'agreement': 430,
#               'committee': 431,
#               'labour': 432,
#               'water': 433,
#               'become': 434,
#               'heart': 435,
#               'america': 436,
#               'ever': 437,
#               'growing': 438,
#               'alliance': 439,
#               'colombo': 440,
#               'elite': 441,
#               'jesus': 442,
#               'whom': 443,
#               'statement': 444,
#               'able': 445,
#               'health': 446,
#               'israeli': 447,
#               'lankan': 448,
#               'large': 449,
#               'once': 450,
#               'politics': 451,
#               'september': 452,
#               'small': 453,
#               'soldiers': 454,
#               'council': 455,
#               'human': 456,
#               'jvp': 457,
#               'local': 458,
#               'point': 459,
#               'whose': 460,
#               'governments': 461,
#               'led': 462,
#               'received': 463,
#               'release': 464,
#               'change': 465,
#               'pass': 466,
#               'rather': 467,
#               'real': 468,
#               'head': 469,
#               'issue': 470,
#               'market': 471,
#               'wife': 472,
#               'family': 473,
#               'increase': 474,
#               'return': 475,
#               'close': 476,
#               'deal': 477,
#               'group': 478,
#               'talks': 479,
#               'basis': 480,
#               'protests': 481,
#               'saw': 482,
#               'six': 483,
#               'capitalism': 484,
#               'plans': 485,
#               'britain': 486,
#               'capital': 487,
#               'coalition': 488,
#               'coming': 489,
#               'full': 490,
#               'thousands': 491,
#               'whole': 492,
#               'leading': 493,
#               'thing': 494,
#               'throughout': 495,
#               "'ll": 496,
#               'began': 497,
#               'making': 498,
#               'open': 499,
#               'protest': 500,
#               'reported': 501,
#               'students': 502,
#               '3': 503,
#               'despite': 504,
#               'groups': 505,
#               'response': 506,
#               'top': 507,
#               'ago': 508,
#               'along': 509,
#               'important': 510,
#               'jerusalem': 511,
#               'less': 512,
#               'near': 513,
#               '20': 514,
#               'conflict': 515,
#               'defence': 516,
#               'service': 517,
#               'speak': 518,
#               'turn': 519,
#               'won': 520,
#               'hands': 521,
#               'pay': 522,
#               'seven': 523,
#               'taking': 524,
#               'words': 525,
#               'egypt': 526,
#               'question': 527,
#               'spoke': 528,
#               'though': 529,
#               'west': 530,
#               'popular': 531,
#               'rightwing': 532,
#               'says': 533,
#               'acting': 534,
#               'development': 535,
#               'fight': 536,
#               'show': 537,
#               'area': 538,
#               'areas': 539,
#               'behind': 540,
#               'heard': 541,
#               'love': 542,
#               'presidential': 543,
#               'sarkozy': 544,
#               '30': 545,
#               'free': 546,
#               'leadership': 547,
#               'hundreds': 548,
#               'lost': 549,
#               'threat': 550,
#               'cuts': 551,
#               'dead': 552,
#               'moses': 553,
#               'plan': 554,
#               'july': 555,
#               'night': 556,
#               'process': 557,
#               'recently': 558,
#               'eat': 559,
#               'parliament': 560,
#               'perspective': 561,
#               'attempt': 562,
#               'conference': 563,
#               'early': 564,
#               'history': 565,
#               'hundred': 566,
#               'later': 567,
#               'obama': 568,
#               'thereof': 569,
#               'third': 570,
#               'lives': 571,
#               'march': 572,
#               'pressure': 573,
#               'stand': 574,
#               'current': 575,
#               'doing': 576,
#               'forth': 577,
#               'april': 578,
#               'cities': 579,
#               'families': 580,
#               'find': 581,
#               'future': 582,
#               'heroine': 583,
#               'carried': 584,
#               'course': 585,
#               'demands': 586,
#               'different': 587,
#               'entire': 588,
#               'imperialism': 589,
#               'line': 590,
#               'production': 591,
#               'yesterday': 592,
#               '5': 593,
#               'budget': 594,
#               'armed': 595,
#               'died': 596,
#               'particularly': 597,
#               'society': 598,
#               'soon': 599,
#               'best': 600,
#               'demand': 601,
#               'establishment': 602,
#               'job': 603,
#               'news': 604,
#               'possible': 605,
#               "'ve": 606,
#               'island': 607,
#               'judah': 608,
#               'member': 609,
#               'sought': 610,
#               'turned': 611,
#               'aid': 612,
#               'asia': 613,
#               'help': 614,
#               'hit': 615,
#               'involved': 616,
#               'nations': 617,
#               'telugu': 618,
#               '4': 619,
#               'brother': 620,
#               'companies': 621,
#               'continue': 622,
#               'form': 623,
#               'instead': 624,
#               'word': 625,
#               '15': 626,
#               'chennai': 627,
#               'continued': 628,
#               'due': 629,
#               'half': 630,
#               'massive': 631,
#               'civil': 632,
#               'fear': 633,
#               'meet': 634,
#               'millions': 635,
#               'offering': 636,
#               'poor': 637,
#               'private': 638,
#               'provide': 639,
#               'significant': 640,
#               'socalled': 641,
#               'special': 642,
#               'supporters': 643,
#               'front': 644,
#               'january': 645,
#               'produced': 646,
#               'sinhala': 647,
#               'white': 648,
#               'banks': 649,
#               'earlier': 650,
#               'independent': 651,
#               'november': 652,
#               'site': 653,
#               'weeks': 654,
#               '11': 655,
#               'across': 656,
#               'civilians': 657,
#               'democracy': 658,
#               'hear': 659,
#               'immediately': 660,
#               'terrorism': 661,
#               'cast': 662,
#               'direct': 663,
#               'equality': 664,
#               'eyes': 665,
#               'side': 666,
#               'towards': 667,
#               'youth': 668,
#               'keep': 669,
#               'known': 670,
#               'northern': 671,
#               'relations': 672,
#               'using': 673,
#               'blair': 674,
#               'blood': 675,
#               'character': 676,
#               'created': 677,
#               'february': 678,
#               'responsible': 679,
#               'school': 680,
#               'sea': 681,
#               'sections': 682,
#               'toward': 683,
#               'voice': 684,
#               'whether': 685,
#               'agreed': 686,
#               'fall': 687,
#               'invasion': 688,
#               'mother': 689,
#               'period': 690,
#               'problems': 691,
#               'russia': 692,
#               'unemployment': 693,
#               'actions': 694,
#               'candidate': 695,
#               'claims': 696,
#               'live': 697,
#               'met': 698,
#               'october': 699,
#               'rajini': 700,
#               'reports': 701,
#               'shot': 702,
#               'above': 703,
#               'august': 704,
#               'became': 705,
#               'each': 706,
#               'evidence': 707,
#               'forced': 708,
#               'seeking': 709,
#               'serious': 710,
#               'something': 711,
#               'thousand': 712,
#               'vijay': 713,
#               '100': 714,
#               'building': 715,
#               'field': 716,
#               'june': 717,
#               'look': 718,
#               'none': 719,
#               'refused': 720,
#               'russian': 721,
#               'terrorist': 722,
#               'communist': 723,
#               'destruction': 724,
#               'function': 725,
#               'organisations': 726,
#               'previous': 727,
#               'violence': 728,
#               "'the": 729,
#               'democrats': 730,
#               'run': 731,
#               'spd': 732,
#               'wsws': 733,
#               'die': 734,
#               'followed': 735,
#               'round': 736,
#               'rule': 737,
#               'speech': 738,
#               'total': 739,
#               'camp': 740,
#               'rest': 741,
#               'base': 742,
#               'basic': 743,
#               'brothers': 744,
#               'daughter': 745,
#               'fighting': 746,
#               'gas': 747,
#               'leave': 748,
#               'necessary': 749,
#               'offer': 750,
#               'opposed': 751,
#               'producer': 752,
#               'ready': 753,
#               'article': 754,
#               'chinese': 755,
#               'poverty': 756,
#               'university': 757,
#               'wall': 758,
#               'york': 759,
#               '40': 760,
#               'air': 761,
#               'alternative': 762,
#               'claim': 763,
#               'decided': 764,
#               'either': 765,
#               'growth': 766,
#               'hours': 767,
#               'lead': 768,
#               'â': 769,
#               'border': 770,
#               'bourgeois': 771,
#               'claimed': 772,
#               'december': 773,
#               'food': 774,
#               '25': 775,
#               'always': 776,
#               'expected': 777,
#               'federal': 778,
#               'gonna': 779,
#               'negotiations': 780,
#               'particular': 781,
#               'post': 782,
#               'reason': 783,
#               'start': 784,
#               'started': 785,
#               'tell': 786,
#               'build': 787,
#               'explained': 788,
#               'industry': 789,
#               'latest': 790,
#               'legal': 791,
#               'limited': 792,
#               'played': 793,
#               'rise': 794,
#               'soviet': 795,
#               'web': 796,
#               'women': 797,
#               '‘': 798,
#               'intelligence': 799,
#               'issues': 800,
#               'move': 801,
#               'nearly': 802,
#               'newspaper': 803,
#               'outside': 804,
#               'palestinian': 805,
#               'similar': 806,
#               '12': 807,
#               'anger': 808,
#               'beginning': 809,
#               'break': 810,
#               'comes': 811,
#               'department': 812,
#               'passed': 813,
#               'presence': 814,
#               'services': 815,
#               'supported': 816,
#               '2002': 817,
#               '2003': 818,
#               '6': 819,
#               'believe': 820,
#               'chirac': 821,
#               'holy': 822,
#               'largest': 823,
#               'masses': 824,
#               'revolution': 825,
#               'thought': 826,
#               'alone': 827,
#               'defend': 828,
#               'information': 829,
#               'morning': 830,
#               'profit': 831,
#               'added': 832,
#               'although': 833,
#               'better': 834,
#               'kamal': 835,
#               'matter': 836,
#               'nato': 837,
#               'revolutionary': 838,
#               '500': 839,
#               'anything': 840,
#               'board': 841,
#               'education': 842,
#               'evil': 843,
#               'song': 844,
#               'strategic': 845,
#               'sunday': 846,
#               'upon': 847,
#               'almost': 848,
#               'authorities': 849,
#               'cause': 850,
#               'decades': 851,
#               'efforts': 852,
#               'ground': 853,
#               'heaven': 854,
#               'increased': 855,
#               'investment': 856,
#               'needs': 857,
#               'series': 858,
#               'socialism': 859,
#               'spirit': 860,
#               'street': 861,
#               'taliban': 862,
#               'unp': 863,
#               'beijing': 864,
#               'candidates': 865,
#               'certain': 866,
#               'demonstrations': 867,
#               'fourth': 868,
#               'issued': 869,
#               'moreover': 870,
#               'musharraf': 871,
#               'send': 872,
#               'wage': 873,
#               'wages': 874,
#               'warned': 875,
#               '50': 876,
#               'aimed': 877,
#               'bjp': 878,
#               'calling': 879,
#               'expressed': 880,
#               'fathers': 881,
#               'greens': 882,
#               'japan': 883,
#               'killing': 884,
#               'raised': 885,
#               'strikes': 886,
#               'strong': 887,
#               'works': 888,
#               'completely': 889,
#               'defense': 890,
#               'monday': 891,
#               'offensive': 892,
#               'organisation': 893,
#               'prepared': 894,
#               'spending': 895,
#               'various': 896,
#               'whatever': 897,
#               'collapse': 898,
#               'common': 899,
#               'cost': 900,
#               'failed': 901,
#               'fell': 902,
#               'freedom': 903,
#               'gone': 904,
#               'immediate': 905,
#               'nation': 906,
#               'noted': 907,
#               'operations': 908,
#               'paid': 909,
#               'pakistani': 910,
#               'problem': 911,
#               'destroyed': 912,
#               'increasingly': 913,
#               'independence': 914,
#               'level': 915,
#               'liberation': 916,
#               'makes': 917,
#               'mean': 918,
#               'operation': 919,
#               'parliamentary': 920,
#               'demanding': 921,
#               'directly': 922,
#               'john': 923,
#               'priest': 924,
#               'questions': 925,
#               'signed': 926,
#               'paris': 927,
#               'provided': 928,
#               'resistance': 929,
#               'sector': 930,
#               'standards': 931,
#               'answer': 932,
#               'association': 933,
#               'body': 934,
#               'daily': 935,
#               'enough': 936,
#               'events': 937,
#               'key': 938,
#               'tensions': 939,
#               'broad': 940,
#               'criminal': 941,
#               'greater': 942,
#               'interest': 943,
#               'returned': 944,
#               'sharon': 945,
#               'tax': 946,
#               'worked': 947,
#               'written': 948,
#               '7': 949,
#               'bill': 950,
#               'bourgeoisie': 951,
#               'constitution': 952,
#               'didn': 953,
#               'energy': 954,
#               'finance': 955,
#               'hospital': 956,
#               'huge': 957,
#               'published': 958,
#               'share': 959,
#               'baghdad': 960,
#               'corporate': 961,
#               'drive': 962,
#               'gold': 963,
#               'imperialist': 964,
#               'lack': 965,
#               'late': 966,
#               'record': 967,
#               'remain': 968,
#               'wanted': 969,
#               '2001': 970,
#               'accept': 971,
#               'demonstration': 972,
#               'labor': 973,
#               'looking': 974,
#               'per': 975,
#               'sign': 976,
#               'concerned': 977,
#               'historical': 978,
#               'hold': 979,
#               'islamic': 980,
#               'prices': 981,
#               'producers': 982,
#               'rate': 983,
#               'rejected': 984,
#               'voters': 985,
#               'wants': 986,
#               '2004': 987,
#               'answered': 988,
#               'civilian': 989,
#               'commanded': 990,
#               'consequences': 991,
#               'demanded': 992,
#               'establish': 993,
#               'price': 994,
#               'seek': 995,
#               'senior': 996,
#               'victory': 997,
#               '8': 998,
#               'ajith': 999,
#               ...}))

# %%
# train_loader,val_loader,test_loader=BucketIterator.splits((train_data,val_data,test_data),
#                                                batch_size=8,
#                                                device=device,
#                                                )

# %%
# batch=next(iter(train_loader))
# print(type(batch))
# batch.tam.shape, batch.eng.shape

# %%
# a

# %%
torch.save({
                'tamil_voc': tamil.vocab.__dict__,
                'english_voc': english.vocab.__dict__,
            },'vocab_tamil_english.pth.tar')

# %% [markdown]
# # transformer

# %%
class _transfomer(nn.Module):
    def __init__(self,embed_size,src_vocab_size,trg_vocab_size,src_pad_idx,
                 num_heads,n_enc_layer,n_dec_layer,forward_expansion,
                 dropout,max_len,device):
        super(_transfomer, self).__init__()
        self.src_embedding=nn.Embedding(src_vocab_size,embed_size) 
        self.src_postion_embedding=nn.Embedding(max_len,embed_size) 
        self.trg_embedding=nn.Embedding(trg_vocab_size,embed_size) 
        self.trg_postion_embedding=nn.Embedding(max_len,embed_size)
        self.device=device 
        self.tranformer=nn.Transformer(embed_size,
                                       num_heads,
                                       n_enc_layer,
                                       n_dec_layer,
                                       forward_expansion,
                                       dropout,
                                       )
        self.fc_out=nn.Linear(embed_size,trg_vocab_size)
        self.dropout=nn.Dropout(dropout)
        self.src_pad_idx=src_pad_idx
        
    def _make_src_mask(self,src):
        src_mask=src.transpose(0,1)==self.src_pad_idx
        return src_mask
    
    def forward(self,src,trg):
        src_seq_len,N=src.shape
        trg_seq_len,N=trg.shape
        
        src_position=(
            torch.arange(0,src_seq_len).unsqueeze(1).expand(src_seq_len,N).to(self.device)
        )
        trg_position=(
            torch.arange(0,trg_seq_len).unsqueeze(1).expand(trg_seq_len,N).to(self.device)
        )
        
        embed_src=self.dropout(
            (self.src_embedding(src) + self.src_postion_embedding(src_position))
            )
        
        embed_trg=self.dropout(
            (self.trg_embedding(trg) + self.trg_postion_embedding(trg_position))
        )
        _src_mask_pad=self._make_src_mask(src)
        trg_mask=self.tranformer.generate_square_subsequent_mask(trg_seq_len).to(self.device)

        out=self.tranformer(
            embed_src,
            embed_trg,
            src_key_padding_mask=_src_mask_pad,
            tgt_mask=trg_mask
        )
        out=self.fc_out(out)
        
        return out

# %% [markdown]
# # Hpyerparameterds

# %%
src_vocab_size=len(english.vocab)
trg_vocab_size=len(tamil.vocab)
num_epochs=100
lr=20**-4
bs=32
# embed_size=512
# num_head=8
embed_size=768
num_head=12
n_ecode_layer=8 #6
n_decode_layer=8
dropout=0.2#2
max_len=100
forward_expansion=4
src_pad_idx=english.vocab.stoi["<pad>"]
writer=SummaryWriter("runs/loss_plot")
pad_idx=english.vocab.stoi["<pad>"]

# %%
train_loader,val_loader,test_loader=BucketIterator.splits((train_data,val_data,test_data),
                                               batch_size=bs,
                                               sort_within_batch=True,
                                               sort_key= lambda x:len(x.eng), 
                                               device=device
                                               )

# %%
model=_transfomer(embed_size,src_vocab_size,trg_vocab_size,
                  src_pad_idx,num_head,n_ecode_layer,n_decode_layer,
                  forward_expansion,dropout,max_len,device).to(device)
optimizer=torch.optim.Adam(model.parameters(),lr=lr)
criterion=nn.CrossEntropyLoss(ignore_index=pad_idx)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, factor=0.1, patience=10, verbose=True
)
# Out:
# /mnt/disk1/conda/envs/gulshan/lib/python3.8/site-packages/torch/nn/modules/transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# /mnt/disk1/conda/envs/gulshan/lib/python3.8/site-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "

# %%
load_model=True
if load_model:
    model = _transfomer(embed_size,src_vocab_size,trg_vocab_size,
                  src_pad_idx,num_head,n_ecode_layer,n_decode_layer,
                  forward_expansion,dropout,max_len,device).to(device)
    _load=torch.load('/mnt/disk1/Gulshan/rnn/translation/checkpoints/6.25e-06_768_12_100.pth.tar')
    _load,op,ep,sh=_load['model'],_load['optimizer'],_load['epoch'],_load['lr_scheduler']
    model.load_state_dict(_load)
    optimizer.load_state_dict(op)
    scheduler.load_state_dict(sh)
    epochs=ep
epochs=50
# Out:
# /mnt/disk1/conda/envs/gulshan/lib/python3.8/site-packages/torch/nn/modules/transformer.py:306: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %% [markdown]
# # training

# %%
def train():
    step=0
    for epoch in tqdm(range(epochs,num_epochs), total=num_epochs):
        
        model.train()
        losses = []
        for batch_idx,batch in enumerate(tqdm(train_loader)):
            src_data=batch.eng.to(device)
            trg_data=batch.tam.to(device)
            # forward
            #trg_data[:-1] -> hey ! good  <end> , src data -> <start> hey ! good
            out=model(src_data,trg_data[:-1])
            out=out.reshape(-1,out.shape[2]) # to keep the last dim 
            trg_data=trg_data[1:].reshape(-1)
            
            optimizer.zero_grad()
            loss=criterion(out,trg_data)
            losses.append(loss.item())
            loss.backward()
            
            nn.utils.clip_grad_norm_(model.parameters(),max_norm=1)
            
            optimizer.step()
            
            writer.add_scalar( "Training loss",loss,global_step=step)
            step+=1
        mean_loss = sum(losses) / len(losses)
        scheduler.step(mean_loss)
        print("The mean loss is",mean_loss)
        if (epoch+1)%5==0:
            print(1)
            state = {'epoch': epoch+1, 'model': model.state_dict(),
                     'optimizer': optimizer.state_dict(),
                     'lr_scheduler':scheduler.state_dict()}
            torch.save(state, f'/mnt/disk1/Gulshan/rnn/translation/checkpoints/{lr}_{embed_size}_{num_head}_' + str(epoch+1) + '.pth.tar')
train()
# 4.233643220424652
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/1000 [00:00<?, ?it/s]
# The mean loss is 5.781579265594482
#   0%|          | 0/1000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 36
#      32             state = {'epoch': epoch+1, 'model': model.state_dict(),
#      33                      'optimizer': optimizer.state_dict(),
#      34                      'lr_scheduler':scheduler.state_dict()}
#      35             torch.save(state, f'/mnt/disk1/Gulshan/rnn/translation/checkpoints/{lr}_{embed_size}_{num_head}_' + str(epoch+1) + '.pth.tar')
# ---> 36 train()
#      37 # 4.233643220424652
#
# Cell In[24], line 12, in train()
#       9 trg_data=batch.tam.to(device)
#      10 # forward
#      11 #trg_data[:-1] -> hey ! good  <end> , src data -> <start> hey ! good
# ---> 12 out=model(src_data,trg_data[:-1])
#      13 out=out.reshape(-1,out.shape[2]) # to keep the last dim
#      14 trg_data=trg_data[1:].reshape(-1)
#
# File /mnt/disk1/conda/envs/gulshan/lib/python3.8/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File /mnt/disk1/conda/envs/gulshan/lib/python3.8/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# Cell In[19], line 34, in _transfomer.forward(self, src, trg)
#      28 trg_seq_len,N=trg.shape
#      30 src_position=(
#      31     torch.arange(0,src_seq_len).unsqueeze(1).expand(src_seq_len,N).to(self.device)
#      32 )
#      33 trg_position=(
# ---> 34     torch.arange(0,trg_seq_len).unsqueeze(1).expand(trg_seq_len,N).to(self.device)
#      35 )
#      37 embed_src=self.dropout(
#      38     (self.src_embedding(src) + self.src_postion_embedding(src_position))
#      39     )
#      41 embed_trg=self.dropout(
#      42     (self.trg_embedding(trg) + self.trg_postion_embedding(trg_position))
#      43 )
#
# KeyboardInterrupt:

# %%
# 4.233643220424652

# %%
_model = _transfomer(embed_size,src_vocab_size,trg_vocab_size,
                  src_pad_idx,num_head,n_ecode_layer,n_decode_layer,
                  forward_expansion,dropout,max_len,device).to(device)
_load=torch.load('/mnt/disk1/Gulshan/rnn/translation/checkpoints/6.25e-06_checkpoint_40.pth.tar')
_load=_load['transformer']
_model.load_state_dict(_load)
# _model
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[78], line 4
#       1 _model = _transfomer(embed_size,src_vocab_size,trg_vocab_size,
#       2                   src_pad_idx,num_head,n_ecode_layer,n_decode_layer,
#       3                   forward_expansion,dropout,max_len,device).to(device)
# ----> 4 _load=torch.load('/mnt/disk1/Gulshan/rnn/translation/checkpoints/6.25e-06_checkpoint_40.pth.tar')
#       5 _load=_load['transformer']
#       6 _model.load_state_dict(_load)
#
# File /mnt/disk1/conda/envs/gulshan/lib/python3.8/site-packages/torch/serialization.py:997, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#     994 if 'encoding' not in pickle_load_args.keys():
#     995     pickle_load_args['encoding'] = 'utf-8'
# --> 997 with _open_file_like(f, 'rb') as opened_file:
#     998     if _is_zipfile(opened_file):
#     999         # The zipfile reader is going to advance the current file position.
#    1000         # If we want to actually tail call to torch.jit.load, we need to
#    1001         # reset back to the original position.
#    1002         orig_position = opened_file.tell()
#
# File /mnt/disk1/conda/envs/gulshan/lib/python3.8/site-packages/torch/serialization.py:444, in _open_file_like(name_or_buffer, mode)
#     442 def _open_file_like(name_or_buffer, mode):
#     443     if _is_path(name_or_buffer):
# --> 444         return _open_file(name_or_buffer, mode)
#     445     else:
#     446         if 'w' in mode:
#
# File /mnt/disk1/conda/envs/gulshan/lib/python3.8/site-packages/torch/serialization.py:425, in _open_file.__init__(self, name, mode)
#     424 def __init__(self, name, mode):
# --> 425     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/disk1/Gulshan/rnn/translation/checkpoints/6.25e-06_checkpoint_40.pth.tar'

# %%
def translate_sentence(_model, sentence, tamil, english, device, max_length=50):
    _model.eval()
    if type(sentence) == str:
        tokens = [token.lower() for token in sentence.split(' ')]
    else:
        tokens = [token.lower() for token in sentence]
    tokens.insert(0, english.init_token)
    tokens.append(english.eos_token)
    text_to_indices = [english.vocab.stoi[token] for token in tokens]
    print(text_to_indices)
    sentence_tensor = torch.LongTensor(text_to_indices).unsqueeze(1).to(device)

    outputs = [tamil.vocab.stoi["<start>"]]
    for i in range(max_length):
        trg_tensor = torch.LongTensor(outputs).unsqueeze(1).to(device)

        with torch.no_grad():
            output = _model(sentence_tensor, trg_tensor)

        best_guess = output.argmax(2)[-1, :].item()

        outputs.append(best_guess)
        if best_guess == tamil.vocab.stoi["<end>"]:
            break

    translated_sentence = [tamil.vocab.itos[idx] for idx in outputs]
    # remove start token
    print(translated_sentence[1:-1])
    output=' '.join([(i) for i in translated_sentence[1:-1]])
    return output

# %%
english.init_token
# Out:
# '<start>'

# %%
sen="come here"
translate_sentence(_model,sen,tamil,english,device)
# Out:
# [2, 122, 235, 3]
# ['நிக்கோலா', 'பேர்லின்', 'பிரச்சினைகளின்', 'செய்யப்படவில்லை', 'வார்த்தைகளில்', 'இருந்தார்', 'பேர்லின்', 'தேடிக்', 'ஊழியர்கள்', 'ரோகல்', 'வார்த்தைகளில்', 'பிரச்சினைகளின்', 'முதலாக', 'பகுதிகள்', 'சொல்லுகிறார்;', 'பூமி', 'மற்றவர்கள்', 'பூசலில்', 'பேர்லின்', 'தெரிகிறது', 'நண்பர்', 'தேடிக்', 'சொல்லுகிறார்;', 'தேடிக்', 'தேடிக்', 'கழுத்தை', 'முன்னெடுக்கும்', 'குமாரதுங்கவின்', 'சொல்லுகிறார்;', 'உனக்கு', 'தேடிக்', 'கூறியதாவது', 'தேடிக்', 'அதேபோல்', 'பெற்றுள்ளார்', 'தேடிக்', 'பேர்லின்', 'தேடிக்', 'இருந்தார்', 'ரஷ்யாவுடன்', 'கூறியதாவது', 'பேர்லின்', 'கூறியதாவது', 'வார்த்தை', 'ஊழியர்கள்', 'பிரச்சினைகளின்', 'வார்த்தைகளில்', 'வார்த்தைகளில்', 'தேடிக்']
# 'நிக்கோலா பேர்லின் பிரச்சினைகளின் செய்யப்படவில்லை வார்த்தைகளில் இருந்தார் பேர்லின் தேடிக் ஊழியர்கள் ரோகல் வார்த்தைகளில் பிரச்சினைகளின் முதலாக பகுதிகள் சொல்லுகிறார்; பூமி மற்றவர்கள் பூசலில் பேர்லின் தெரிகிறது நண்பர் தேடிக் சொல்லுகிறார்; தேடிக் தேடிக் கழுத்தை முன்னெடுக்கும் குமாரதுங்கவின் சொல்லுகிறார்; உனக்கு தேடிக் கூறியதாவது தேடிக் அதேபோல் பெற்றுள்ளார் தேடிக் பேர்லின் தேடிக் இருந்தார் ரஷ்யாவுடன் கூறியதாவது பேர்லின் கூறியதாவது வார்த்தை ஊழியர்கள் பிரச்சினைகளின் வார்த்தைகளில் வார்த்தைகளில் தேடிக்'

# %%
def bleu(data, model, tamil, english, device):
    targets = []
    outputs = []

    for example in data:
        src = vars(example)["src"]
        trg = vars(example)["trg"]

        prediction = translate_sentence(model, src, tamil, english, device)
        prediction = prediction[:-1]  # remove <eos> token

        targets.append([trg])
        outputs.append(prediction)

    return bleu_score(outputs, targets)
